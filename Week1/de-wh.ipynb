# %% [markdown]
# # Data Talks Data Engineer Course Home Work
# ### Source of Data to be inserted in Postgress for homework
# wget https://github.com/DataTalksClub/nyc-tlc-data/releases/download/green/green_tripdata_2019-10.csv.gz
# wget https://github.com/DataTalksClub/nyc-tlc-data/releases/download/misc/taxi_zone_lookup.csv
#
#     TIP:- As we can see the source file is zip in gz format so we have to extract it before loading it into PostgreSQL

# %% [markdown]
# # Section A
# ## Writing the ingest.py file to be used in Data ingestor container
#     STEP 1: Import necessary python library for the script

# %%
# %%writefile ingest1.py


import os
import argparse
import gzip
import shutil
import pandas as pd
from sqlalchemy import create_engine
from time import time
# Out:
# Overwriting ingest1.py

# %% [markdown]
#     Step 2: Defining the parameter given by user

# %%
# %%writefile -a ingest1.py

def main(param):
    user = param.user
    password = param.password
    db = param.db
    host = param.host
    port = param.port
    table_name = param.table_name
    file_url = param.file_url
# Out:
# Appending to ingest1.py

# %% [markdown]
#     Step 3: Download data from git hub as instructed and extract CSV file

# %%
# %%writefile -a ingest1.py


 # ✅ Auto-generate output filename from URL
    output_file = file_url.split('/')[-1]

    # Download the file
    print(f"📥 Downloading file from {file_url}")
    os.system(f"wget {file_url} -O {output_file}")
    print(f"⬇️  Downloading: {file_url}")


    # If file is compressed (.gz), extract it
    if output_file.endswith(".gz"):
        extracted_file = output_file.replace(".gz", "")
        print(f"🗜️ Extracting compressed file: {output_file} → {extracted_file}")
        with gzip.open(output_file, 'rb') as f_in:
            with open(extracted_file, 'wb') as f_out:
                shutil.copyfileobj(f_in, f_out)
        print("✅ Extraction complete.")
    else:
        print("✅ File is not compressed, proceeding normally.")
        csv_file = output_file
# Out:
# Appending to ingest1.py

# %% [markdown]
#     Step 4: Connect with pg-database docker container and create our table inside our ny-taxi DB

# %%
# %%writefile -a ingest1.py 

    print(f"🚀 Connecting to Postgres: {host}:{port}/{db}")
    engine = create_engine(f'postgresql://{user}:{password}@{host}:{port}/{db}')
    print("Connected to ",engine.connect(), " postgress server")

    print(f"📄 Reading data from {csv_file}")
    df_iter = pd.read_csv(csv_file, iterator=True, chunksize=100000)

    # Create table schema
    df = next(df_iter)
    df.head(0).to_sql(name=table_name, con=engine, if_exists='replace')
# Out:
# Appending to ingest1.py

# %% [markdown]
#     Step 5: Ingesting data in chunks of managmanageable size of postgress

# %%
# %%writefile -a ingest1.py


    while True:
        try:
            t_start = time()
            df = next(df_iter)

            # ✅ Handle both green & yellow taxi schemas
            datetime_cols = [col for col in df.columns if 'pickup_datetime' in col or 'dropoff_datetime' in col]
            for col in datetime_cols:
                df[col] = pd.to_datetime(df[col])

            df.to_sql(name=table_name, con=engine, if_exists='append', index=False)

            t_end = time()
            print(f"✅ Inserted chunk in {t_end - t_start:.3f} seconds")

        except StopIteration:
            print("🏁 Ingestion complete — no more chunks to process.")
            break
        except Exception as e:
            print(f"❌ Error processing chunk: {e}")
            break


if __name__ == '__main__':
    parser = argparse.ArgumentParser(description='Ingest CSV or GZ data to Postgres')

    parser.add_argument('--user', required=True, help='username for postgres')
    parser.add_argument('--password', required=True, help='password for postgres')
    parser.add_argument('--host', required=True, help='host for postgres')
    parser.add_argument('--port', required=True, help='port for postgres')
    parser.add_argument('--db', required=True, help='database name for postgres')
    parser.add_argument('--table_name', required=True, help='table name for postgres')
    parser.add_argument('--file_url', required=True, help='URL of the CSV or GZ file')

    args = parser.parse_args()
    main(args)
# Out:
# Appending to ingest1.py

# %% [markdown]
# # Section B
#
#     Step1: Creating Docker-Compose.yml File

# %%
# %%writefile docker-compose.yml
#
# services:
#   postgres:
#     image: postgres:13
#     container_name: pg-database
#     environment:
#       - POSTGRES_USER=root
#       - POSTGRES_PASSWORD=root
#       - POSTGRES_DB=ny_taxi
#     ports:
#       - "5432:5432"
#     volumes:
#       - ./ny_taxi_postgres_data:/var/lib/postgresql/data
#     networks:
#       - pg-network
#
#   pgadmin:
#     image: dpage/pgadmin4
#     container_name: pgadmin
#     environment:
#       - PGADMIN_DEFAULT_EMAIL=admin@admin.com
#       - PGADMIN_DEFAULT_PASSWORD=admin
#     ports:
#       - "8080:80"
#     depends_on:
#       - postgres
#     networks:
#       - pg-network
#
# networks:
#   pg-network:
#     driver: bridge
# Out:
# Overwriting docker-compose.yml

# %% [markdown]
#     Step 2: Creating a docker file for our Ingestor container(using Ingest1.py).

# %%
# %%writefile dockerfile
#
# FROM python:3.12.8
# WORKDIR /app
#
# # Install wget
# RUN apt-get update && apt-get install -y wget && apt-get clean
#
# # Install Python dependencies
# RUN pip install --no-cache-dir pandas sqlalchemy psycopg2-binary
#
# # Create archive directory inside container
# RUN mkdir -p /app/archive
#
# # Copy local files into container
# COPY ingest.py /app/ingest.py
# COPY archive/ /app/archive/
#
# # Run the Python script
# ENTRYPOINT ["python", "ingest.py"]
# Out:
# Overwriting dockerfile

# %% [markdown]
# ## Section C
#     Launching the docker-compose continer using terminal
# step 1:$docker-compose up -d
# step 2:$docker build -t [container-name]
# step 3: Checking  network name used by compose container
#           $docker network ls [look for your docker-compose network]
# step 4: Run the continer create in step2
#           $docker run -it --network=[your compose network] [continer-name] \
#                     --user=root \
#                     --password=root \
#                     --db=ny_taxi \
#                     --host=pg-database \
#                     --port=5432 \
#                     --table_name=hw-green \
#                     --file_url=https://github.com/DataTalksClub/nyc-tlc-data/releases/download/green/green_tripdata_2019-10.csv.gz

# %%
# !docker compose up -d
# Out:
# 18603.34s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# [+] Running 0/2
#  ⠙ postgres Pulling                                                        0.1s
#  ⠙ pgadmin Pulling                                                         0.1s
# [+] Running 0/2
#  ⠹ postgres Pulling                                                        0.2s
#  ⠹ pgadmin Pulling                                                         0.2s
# [+] Running 0/2
#  ⠸ postgres Pulling                                                        0.3s
#  ⠸ pgadmin Pulling                                                         0.3s
# [+] Running 0/2
#  ⠼ postgres Pulling                                                        0.4s
#  ⠼ pgadmin Pulling                                                         0.4s
# [+] Running 0/2
#  ⠴ postgres Pulling                                                        0.5s
#  ⠴ pgadmin Pulling                                                         0.5s
# [+] Running 0/2
#  ⠦ postgres Pulling                                                        0.6s
#  ⠦ pgadmin Pulling                                                         0.6s
# [+] Running 0/2
#  ⠧ postgres Pulling                                                        0.7s
#  ⠧ pgadmin Pulling                                                         0.7s
# [+] Running 0/2
#  ⠇ postgres Pulling                                                        0.8s
#  ⠇ pgadmin Pulling                                                         0.8s
# [+] Running 0/2
#  ⠏ postgres Pulling                                                        0.9s
#  ⠏ pgadmin Pulling                                                         0.9s
# [+] Running 0/2
#  ⠋ postgres Pulling                                                        1.0s
#  ⠋ pgadmin Pulling                                                         1.0s
# [+] Running 0/2
#  ⠙ postgres Pulling                                                        1.1s
#  ⠙ pgadmin Pulling                                                         1.1s
# [+] Running 0/2
#  ⠹ postgres Pulling                                                        1.2s
#  ⠹ pgadmin Pulling                                                         1.2s
# [+] Running 0/2
#  ⠸ postgres Pulling                                                        1.3s
#  ⠸ pgadmin Pulling                                                         1.3s
# [+] Running 0/2
#  ⠼ postgres Pulling                                                        1.4s
#  ⠼ pgadmin Pulling                                                         1.4s
# [+] Running 5/8
#  ⠴ postgres [⣿⣶⣿⣿⣿⣿] 95.42MB / 108.8MB Pulling                             1.5s
#    ✔ a8bfeed3b03a Already exists                                           0.0s
#    ⠋ 315c5a49c3d0 Downloading   95.42MB/108.8MB                            0.1s
#    ✔ 51f3f8ab4bb5 Already exists                                           0.0s
#    ✔ 04f6eb12164f Already exists                                           0.0s
#    ✔ 38d80feef54e Already exists                                           0.0s
#    ✔ 626110df8c5f Already exists                                           0.0s
#  ⠴ pgadmin Pulling                                                         1.5s
# [+] Running 5/8
#  ⠦ postgres [⣿⣶⣿⣿⣿⣿] 95.42MB / 108.8MB Pulling                             1.6s
#    ✔ a8bfeed3b03a Already exists                                           0.0s
#    ⠙ 315c5a49c3d0 Downloading   95.42MB/108.8MB                            0.2s
#    ✔ 51f3f8ab4bb5 Already exists                                           0.0s
#    ✔ 04f6eb12164f Already exists                                           0.0s
#    ✔ 38d80feef54e Already exists                                           0.0s
#    ✔ 626110df8c5f Already exists                                           0.0s
#  ⠦ pgadmin Pulling                                                         1.6s
# [+] Running 5/8
#  ⠧ postgres [⣿⣶⣿⣿⣿⣿] 95.42MB / 108.8MB Pulling                             1.7s
#    ✔ a8bfeed3b03a Already exists                                           0.0s
#    ⠹ 315c5a49c3d0 Downloading   95.42MB/108.8MB                            0.3s
#    ✔ 51f3f8ab4bb5 Already exists                                           0.0s
#    ✔ 04f6eb12164f Already exists                                           0.0s
#    ✔ 38d80feef54e Already exists                                           0.0s
#    ✔ 626110df8c5f Already exists                                           0.0s
#  ⠧ pgadmin Pulling                                                         1.7s
# [+] Running 5/8
#  ⠇ postgres [⣿⣶⣿⣿⣿⣿] 95.42MB / 108.8MB Pulling                             1.8s
#    ✔ a8bfeed3b03a Already exists                                           0.0s
#    ⠸ 315c5a49c3d0 Downloading   95.42MB/108.8MB                            0.4s
#    ✔ 51f3f8ab4bb5 Already exists                                           0.0s
#    ✔ 04f6eb12164f Already exists                                           0.0s
#    ✔ 38d80feef54e Already exists                                           0.0s
#    ✔ 626110df8c5f Already exists                                           0.0s
#  ⠇ pgadmin Pulling                                                         1.8s
# [+] Running 5/8
#  ⠏ postgres [⣿⣶⣿⣿⣿⣿] 95.42MB / 108.8MB Pulling                             1.9s
#    ✔ a8bfeed3b03a Already exists                                           0.0s
#    ⠼ 315c5a49c3d0 Downloading   95.42MB/108.8MB                            0.5s
#    ✔ 51f3f8ab4bb5 Already exists                                           0.0s
#    ✔ 04f6eb12164f Already exists                                           0.0s
#    ✔ 38d80feef54e Already exists                                           0.0s
#    ✔ 626110df8c5f Already exists                                           0.0s
#  ⠏ pgadmin Pulling                                                         1.9s
# [+] Running 5/8
#  ⠋ postgres [⣿⣶⣿⣿⣿⣿] 95.42MB / 108.8MB Pulling                             2.0s
#    ✔ a8bfeed3b03a Already exists                                           0.0s
#    ⠴ 315c5a49c3d0 Downloading   95.42MB/108.8MB                            0.6s
#    ✔ 51f3f8ab4bb5 Already exists                                           0.0s
#    ✔ 04f6eb12164f Already exists                                           0.0s
#    ✔ 38d80feef54e Already exists                                           0.0s
#    ✔ 626110df8c5f Already exists                                           0.0s
#  ⠋ pgadmin Pulling                                                         2.0s
# [+] Running 5/8
#  ⠙ postgres [⣿⣶⣿⣿⣿⣿] 95.42MB / 108.8MB Pulling                             2.1s
#    ✔ a8bfeed3b03a Already exists                                           0.0s
#    ⠦ 315c5a49c3d0 Downloading   95.42MB/108.8MB                            0.7s
#    ✔ 51f3f8ab4bb5 Already exists                                           0.0s
#    ✔ 04f6eb12164f Already exists                                           0.0s
#    ✔ 38d80feef54e Already exists                                           0.0s
#    ✔ 626110df8c5f Already exists                                           0.0s
#  ⠙ pgadmin Pulling                                                         2.1s
# [+] Running 5/8
#  ⠹ postgres [⣿⣶⣿⣿⣿⣿] 95.42MB / 108.8MB Pulling                             2.2s
#    ✔ a8bfeed3b03a Already exists                                           0.0s
#    ⠧ 315c5a49c3d0 Downloading   95.42MB/108.8MB                            0.8s
#    ✔ 51f3f8ab4bb5 Already exists                                           0.0s
#    ✔ 04f6eb12164f Already exists                                           0.0s
#    ✔ 38d80feef54e Already exists                                           0.0s
#    ✔ 626110df8c5f Already exists                                           0.0s
#  ⠹ pgadmin Pulling                                                         2.2s
# [+] Running 5/8
#  ⠸ postgres [⣿⣶⣿⣿⣿⣿] 95.42MB / 108.8MB Pulling                             2.3s
#    ✔ a8bfeed3b03a Already exists                                           0.0s
#    ⠇ 315c5a49c3d0 Downloading   95.42MB/108.8MB                            0.9s
#    ✔ 51f3f8ab4bb5 Already exists                                           0.0s
#    ✔ 04f6eb12164f Already exists                                           0.0s
#    ✔ 38d80feef54e Already exists                                           0.0s
#    ✔ 626110df8c5f Already exists                                           0.0s
#  ⠸ pgadmin Pulling                                                         2.3s
# [+] Running 5/8
#  ⠼ postgres [⣿⣶⣿⣿⣿⣿] 95.42MB / 108.8MB Pulling                             2.4s
#    ✔ a8bfeed3b03a Already exists                                           0.0s
#    ⠏ 315c5a49c3d0 Downloading   95.42MB/108.8MB                            1.0s
#    ✔ 51f3f8ab4bb5 Already exists                                           0.0s
#    ✔ 04f6eb12164f Already exists                                           0.0s
#    ✔ 38d80feef54e Already exists                                           0.0s
#    ✔ 626110df8c5f Already exists                                           0.0s
#  ⠼ pgadmin Pulling                                                         2.4s
# [+] Running 5/8
#  ⠴ postgres [⣿⣶⣿⣿⣿⣿] 95.42MB / 108.8MB Pulling                             2.5s
#    ✔ a8bfeed3b03a Already exists                                           0.0s
#    ⠋ 315c5a49c3d0 Downloading   95.42MB/108.8MB                            1.1s
#    ✔ 51f3f8ab4bb5 Already exists                                           0.0s
#    ✔ 04f6eb12164f Already exists                                           0.0s
#    ✔ 38d80feef54e Already exists                                           0.0s
#    ✔ 626110df8c5f Already exists                                           0.0s
#  ⠴ pgadmin Pulling                                                         2.5s
# [+] Running 5/8
#  ⠦ postgres [⣿⣶⣿⣿⣿⣿] 95.42MB / 108.8MB Pulling                             2.6s
#    ✔ a8bfeed3b03a Already exists                                           0.0s
#    ⠙ 315c5a49c3d0 Downloading   95.42MB/108.8MB                            1.2s
#    ✔ 51f3f8ab4bb5 Already exists                                           0.0s
#    ✔ 04f6eb12164f Already exists                                           0.0s
#    ✔ 38d80feef54e Already exists                                           0.0s
#    ✔ 626110df8c5f Already exists                                           0.0s
#  ⠦ pgadmin Pulling                                                         2.6s
# [+] Running 5/8
#  ⠧ postgres [⣿⣶⣿⣿⣿⣿] 95.42MB / 108.8MB Pulling                             2.7s
#    ✔ a8bfeed3b03a Already exists                                           0.0s
#    ⠹ 315c5a49c3d0 Downloading   95.42MB/108.8MB                            1.3s
#    ✔ 51f3f8ab4bb5 Already exists                                           0.0s
#    ✔ 04f6eb12164f Already exists                                           0.0s
#    ✔ 38d80feef54e Already exists                                           0.0s
#    ✔ 626110df8c5f Already exists                                           0.0s
#  ⠧ pgadmin Pulling                                                         2.7s
# [+] Running 5/8
#  ⠇ postgres [⣿⣶⣿⣿⣿⣿] 95.42MB / 108.8MB Pulling                             2.8s
#    ✔ a8bfeed3b03a Already exists                                           0.0s
#    ⠸ 315c5a49c3d0 Downloading   95.42MB/108.8MB                            1.4s
#    ✔ 51f3f8ab4bb5 Already exists                                           0.0s
#    ✔ 04f6eb12164f Already exists                                           0.0s
#    ✔ 38d80feef54e Already exists                                           0.0s
#    ✔ 626110df8c5f Already exists                                           0.0s
#  ⠇ pgadmin Pulling                                                         2.8s
# [+] Running 5/8
#  ⠏ postgres [⣿⣶⣿⣿⣿⣿] 95.42MB / 108.8MB Pulling                             2.9s
#    ✔ a8bfeed3b03a Already exists                                           0.0s
#    ⠼ 315c5a49c3d0 Downloading   95.42MB/108.8MB                            1.5s
#    ✔ 51f3f8ab4bb5 Already exists                                           0.0s
#    ✔ 04f6eb12164f Already exists                                           0.0s
#    ✔ 38d80feef54e Already exists                                           0.0s
#    ✔ 626110df8c5f Already exists                                           0.0s
#  ⠏ pgadmin Pulling                                                         2.9s
# [+] Running 5/8
#  ⠋ postgres [⣿⣶⣿⣿⣿⣿] 95.42MB / 108.8MB Pulling                             3.0s
#    ✔ a8bfeed3b03a Already exists                                           0.0s
#    ⠴ 315c5a49c3d0 Downloading   95.42MB/108.8MB                            1.6s
#    ✔ 51f3f8ab4bb5 Already exists                                           0.0s
#    ✔ 04f6eb12164f Already exists                                           0.0s
#    ✔ 38d80feef54e Already exists                                           0.0s
#    ✔ 626110df8c5f Already exists                                           0.0s
#  ⠋ pgadmin Pulling                                                         3.0s
# [+] Running 5/23
#  ⠙ postgres [⣿⣷⣿⣿⣿⣿] 97.52MB / 108.8MB Pulling                             3.1s
#  ⠙ pgadmin [⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀] Pulling                                       3.1s
#
#
#
#
#
#
# [+] Running 5/23
#  ⠹ postgres [⣿⣷⣿⣿⣿⣿] 98.57MB / 108.8MB Pulling                             3.2s
#  ⠹ pgadmin [⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀] Pulling                                       3.2s
#
#
#
#
#
#
# [+] Running 5/23
#  ⠸ postgres [⣿⣷⣿⣿⣿⣿] 99.61MB / 108.8MB Pulling                             3.3s
#  ⠸ pgadmin [⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀] Pulling                                       3.3s
#
#
#
#
#
#
# [+] Running 5/23
#  ⠼ postgres [⣿⣷⣿⣿⣿⣿] 100.7MB / 108.8MB Pulling                             3.4s
#  ⠼ pgadmin [⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀] Pulling                                       3.4s
#
#
#
#
#
#
# [+] Running 5/23
#  ⠴ postgres [⣿⣷⣿⣿⣿⣿] 100.7MB / 108.8MB Pulling                             3.5s
#  ⠴ pgadmin [⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀] Pulling                                       3.5s
#
#
#
#
#
#
# [+] Running 5/23
#  ⠦ postgres [⣿⣷⣿⣿⣿⣿] 100.7MB / 108.8MB Pulling                             3.6s
#  ⠦ pgadmin [⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀] Pulling                                       3.6s
#
#
#
#
#
#
# [+] Running 5/23
#  ⠧ postgres [⣿⣷⣿⣿⣿⣿] 100.7MB / 108.8MB Pulling                             3.7s
#  ⠧ pgadmin [⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀] Pulling                                       3.7s
#
#
#
#
#
#
# [+] Running 5/23
#  ⠇ postgres [⣿⣷⣿⣿⣿⣿] 100.7MB / 108.8MB Pulling                             3.8s
#  ⠇ pgadmin [⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀] Pulling                                       3.8s
#
#
#
#
#
#
# [+] Running 5/23
#  ⠏ postgres [⣿⣷⣿⣿⣿⣿] 100.7MB / 108.8MB Pulling                             3.9s
#  ⠏ pgadmin [⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀] Pulling                                       3.9s
#
#
#
#
#
#
# [+] Running 5/23
#  ⠋ postgres [⣿⣷⣿⣿⣿⣿] 101.7MB / 108.8MB Pulling                             4.0s
#  ⠋ pgadmin [⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀] Pulling                                       4.0s
#
#
#
#
#
#
# [+] Running 6/23
#  ⠙ postgres [⣿⣷⣿⣿⣿⣿] 102.8MB / 108.8MB Pulling                             4.1s
#  ⠙ pgadmin [⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣿⠀⠀⠀] Pulling                                       4.1s
#
#
#
#
#
#
# [+] Running 8/23
#  ⠹ postgres [⣿⣷⣿⣿⣿⣿] 102.8MB / 108.8MB Pulling                             4.2s
#  ⠹ pgadmin [⠀⠀⠀⠀⠀⠀⣿⣿⠀⠀⠀⣿⠀⠀⠀] Pulling                                       4.2s
#
#
#
#
#
#
# [+] Running 9/23
#  ⠸ postgres [⣿⣷⣿⣿⣿⣿] 102.8MB / 108.8MB Pulling                             4.3s
#  ⠸ pgadmin [⠀⠀⠀⠀⠀⠀⣿⣿⠀⠀⣿⣿⠀⣿⠀] Pulling                                       4.3s
#
#
#
#
#
#
# [+] Running 10/23
#  ⠼ postgres [⣿⣷⣿⣿⣿⣿] 103.8MB / 108.8MB Pulling                             4.4s
#  ⠼ pgadmin [⠀⠀⠀⠀⠀⠀⣿⣿⠀⠀⣿⣿⠀⣿⠀] Pulling                                       4.4s
#
#
#
#
#
#
# [+] Running 11/23
#  ⠴ postgres [⣿⣷⣿⣿⣿⣿] 103.8MB / 108.8MB Pulling                             4.5s
#  ⠴ pgadmin [⠀⠀⠀⠀⠀⠀⣿⣿⠀⠀⣿⣿⣿⣿⠀] Pulling                                       4.5s
#
#
#
#
#
#
# [+] Running 11/23
#  ⠦ postgres [⣿⣷⣿⣿⣿⣿] 103.8MB / 108.8MB Pulling                             4.6s
#  ⠦ pgadmin [⠀⠀⣿⠀⠀⠀⣿⣿⠀⠀⣿⣿⣿⣿⠀] Pulling                                       4.6s
#
#
#
#
#
#
# [+] Running 12/23
#  ⠧ postgres [⣿⣷⣿⣿⣿⣿] 103.8MB / 108.8MB Pulling                             4.7s
#  ⠧ pgadmin [⠀⠀⣿⠀⠀⠀⣿⣿⠀⠀⣿⣿⣿⣿⠀] Pulling                                       4.7s
#
#
#
#
#
#
# [+] Running 12/23
#  ⠇ postgres [⣿⣷⣿⣿⣿⣿] 104.9MB / 108.8MB Pulling                             4.8s
#  ⠇ pgadmin [⠀⠀⣿⠀⠀⠀⣿⣿⠀⠀⣿⣿⣿⣿⠀] Pulling                                       4.8s
#
#
#
#
#
#
# [+] Running 12/23
#  ⠏ postgres [⣿⣷⣿⣿⣿⣿] 104.9MB / 108.8MB Pulling                             4.9s
#  ⠏ pgadmin [⠀⠀⣿⠀⠀⠀⣿⣿⠀⠀⣿⣿⣿⣿⠀] Pulling                                       4.9s
#
#
#
#
#
#
# [+] Running 12/23
#  ⠋ postgres [⣿⣷⣿⣿⣿⣿] 104.9MB / 108.8MB Pulling                             5.0s
#  ⠋ pgadmin [⠀⠀⣿⠀⠀⠀⣿⣿⠀⠀⣿⣿⣿⣿⠀] Pulling                                       5.0s
#
#
#
#
#
#
# [+] Running 13/23
#  ⠙ postgres [⣿⣷⣿⣿⣿⣿] 104.9MB / 108.8MB Pulling                             5.1s
#  ⠙ pgadmin [⠀⠀⣿⠀⣿⠀⣿⣿⠀⠀⣿⣿⣿⣿⠀] Pulling                                       5.1s
#
#
#
#
#
#
# [+] Running 13/23
#  ⠹ postgres [⣿⣷⣿⣿⣿⣿] 104.9MB / 108.8MB Pulling                             5.2s
#  ⠹ pgadmin [⠀⠀⣿⠀⣿⠀⣿⣿⠀⠀⣿⣿⣿⣿⠀] Pulling                                       5.2s
#
#
#
#
#
#
# [+] Running 13/23
#  ⠸ postgres [⣿⣷⣿⣿⣿⣿] 105.9MB / 108.8MB Pulling                             5.3s
#  ⠸ pgadmin [⠀⠀⣿⠀⣿⠀⣿⣿⠀⠀⣿⣿⣿⣿⠀] Pulling                                       5.3s
#
#
#
#
#
#
# [+] Running 13/23
#  ⠼ postgres [⣿⣷⣿⣿⣿⣿] 105.9MB / 108.8MB Pulling                             5.4s
#  ⠼ pgadmin [⠀⠀⣿⠀⣿⠀⣿⣿⠀⠀⣿⣿⣿⣿⠀] Pulling                                       5.4s
#
#
#
#
#
#
# [+] Running 13/23
#  ⠴ postgres [⣿⣷⣿⣿⣿⣿] 105.9MB / 108.8MB Pulling                             5.5s
#  ⠴ pgadmin [⠀⠀⣿⠀⣿⠀⣿⣿⠀⠀⣿⣿⣿⣿⠀] Pulling                                       5.5s
#
#
#
#
#
#
# [+] Running 13/23
#  ⠦ postgres [⣿⣷⣿⣿⣿⣿]   107MB / 108.8MB Pulling                             5.6s
#  ⠦ pgadmin [⠀⠀⣿⠀⣿⠀⣿⣿⠀⠀⣿⣿⣿⣿⠀] Pulling                                       5.6s
#
#
#
#
#
#
# [+] Running 13/23
#  ⠧ postgres [⣿⣷⣿⣿⣿⣿]   107MB / 108.8MB Pulling                             5.7s
#  ⠧ pgadmin [⠀⠀⣿⠀⣿⠀⣿⣿⠀⠀⣿⣿⣿⣿⠀] Pulling                                       5.7s
#
#
#
#
#
#
# [+] Running 13/23
#  ⠇ postgres [⣿⣷⣿⣿⣿⣿]   107MB / 108.8MB Pulling                             5.8s
#  ⠇ pgadmin [⠀⠀⣿⠀⣿⠀⣿⣿⠀⠀⣿⣿⣿⣿⠀] Pulling                                       5.8s
#
#
#
#
#
#
# [+] Running 13/23
#  ⠏ postgres [⣿⣷⣿⣿⣿⣿]   108MB / 108.8MB Pulling                             5.9s
#  ⠏ pgadmin [⠀⠀⣿⠀⣿⠀⣿⣿⠀⠀⣿⣿⣿⣿⠀] Pulling                                       5.9s
#
#
#
#
#
#
# [+] Running 13/23
#  ⠋ postgres [⣿⣷⣿⣿⣿⣿]   108MB / 108.8MB Pulling                             6.0s
#  ⠋ pgadmin [⠀⠀⣿⠀⣿⠀⣿⣿⠀⠀⣿⣿⣿⣿⠀] Pulling                                       6.0s
#
#
#
#
#
#
# [+] Running 13/23
#  ⠙ postgres [⣿⣷⣿⣿⣿⣿]   108MB / 108.8MB Pulling                             6.1s
#  ⠙ pgadmin [⠀⠀⣿⠀⣿⠀⣿⣿⠀⠀⣿⣿⣿⣿⠀] Pulling                                       6.1s
#
#
#
#
#
#
# [+] Running 13/23
#  ⠹ postgres [⣿⣿⣿⣿⣿⣿] 108.8MB / 108.8MB Pulling                             6.2s
#  ⠹ pgadmin [⣀⠀⣿⠀⣿⠀⣿⣿⠀⠀⣿⣿⣿⣿⠀] Pulling                                       6.2s
#
#
#
#
#
#
# [+] Running 13/23
#  ⠸ postgres [⣿⣿⣿⣿⣿⣿] 108.8MB / 108.8MB Pulling                             6.3s
#  ⠸ pgadmin [⣀⠀⣿⠀⣿⠀⣿⣿⠀⠀⣿⣿⣿⣿⠀] Pulling                                       6.3s
#
#
#
#
#
#
# [+] Running 13/23
#  ⠼ postgres [⣿⣿⣿⣿⣿⣿] 108.8MB / 108.8MB Pulling                             6.4s
#  ⠼ pgadmin [⣀⠀⣿⠀⣿⠀⣿⣿⠀⠀⣿⣿⣿⣿⠀] Pulling                                       6.4s
#
#
#
#
#
#
# [+] Running 13/23
#  ⠴ postgres [⣿⣿⣿⣿⣿⣿] 108.8MB / 108.8MB Pulling                             6.5s
#  ⠴ pgadmin [⣀⠀⣿⠀⣿⠀⣿⣿⠀⠀⣿⣿⣿⣿⠀] Pulling                                       6.5s
#
#
#
#
#
#
# [+] Running 13/23
#  ⠦ postgres [⣿⣿⣿⣿⣿⣿] 108.8MB / 108.8MB Pulling                             6.6s
#  ⠦ pgadmin [⣀⠀⣿⠀⣿⠀⣿⣿⠀⠀⣿⣿⣿⣿⠀] Pulling                                       6.6s
#
#
#
#
#
#
# [+] Running 13/23
#  ⠧ postgres [⣿⣿⣿⣿⣿⣿] 108.8MB / 108.8MB Pulling                             6.7s
#  ⠧ pgadmin [⣀⠀⣿⠀⣿⠀⣿⣿⠀⠀⣿⣿⣿⣿⠀] Pulling                                       6.7s
#
#
#
#
#
#
# [+] Running 14/23
#  ⠇ postgres [⣿⣿⣿⣿⣿⣿] 108.8MB / 108.8MB Pulling                             6.8s
#  ⠇ pgadmin [⣀⠀⣿⠀⣿⣿⣿⣿⠀⠀⣿⣿⣿⣿⠀] Pulling                                       6.8s
#
#
#
#
#
#
# [+] Running 14/23
#  ⠏ postgres [⣿⣿⣿⣿⣿⣿] 108.8MB / 108.8MB Pulling                             6.9s
#  ⠏ pgadmin [⣀⠀⣿⠀⣿⣿⣿⣿⠀⠀⣿⣿⣿⣿⠀] Pulling                                       6.9s
#
#
#
#
#
#
# [+] Running 14/23
#  ⠋ postgres [⣿⣿⣿⣿⣿⣿] 108.8MB / 108.8MB Pulling                             7.0s
#  ⠋ pgadmin [⣀⠀⣿⠀⣿⣿⣿⣿⠀⠀⣿⣿⣿⣿⠀] Pulling                                       7.0s
#
#
#
#
#
#
# [+] Running 14/23
#  ⠙ postgres [⣿⣿⣿⣿⣿⣿] 108.8MB / 108.8MB Pulling                             7.1s
#  ⠙ pgadmin [⣀⠀⣿⠀⣿⣿⣿⣿⠀⠀⣿⣿⣿⣿⠀] Pulling                                       7.1s
#
#
#
#
#
#
# [+] Running 14/23
#  ⠹ postgres [⣿⣿⣿⣿⣿⣿] 108.8MB / 108.8MB Pulling                             7.2s
#  ⠹ pgadmin [⣀⠀⣿⠀⣿⣿⣿⣿⠀⠀⣿⣿⣿⣿⠀] Pulling                                       7.2s
#
#
#
#
#
#
# [+] Running 14/23
#  ⠸ postgres [⣿⣿⣿⣿⣿⣿] 108.8MB / 108.8MB Pulling                             7.3s
#  ⠸ pgadmin [⣀⠀⣿⠀⣿⣿⣿⣿⠀⠀⣿⣿⣿⣿⠀] Pulling                                       7.3s
#
#
#
#
#
#
# [+] Running 14/23
#  ⠼ postgres [⣿⣿⣿⣿⣿⣿] 108.8MB / 108.8MB Pulling                             7.4s
#  ⠼ pgadmin [⣀⠀⣿⠀⣿⣿⣿⣿⠀⠀⣿⣿⣿⣿⠀] Pulling                                       7.4s
#
#
#
#
#
#
# [+] Running 14/23
#  ⠴ postgres [⣿⣿⣿⣿⣿⣿] 108.8MB / 108.8MB Pulling                             7.5s
#  ⠴ pgadmin [⣀⠀⣿⠀⣿⣿⣿⣿⠀⠀⣿⣿⣿⣿⠀] Pulling                                       7.5s
#
#
#
#
#
#
# [+] Running 14/23
#  ⠦ postgres [⣿⣿⣿⣿⣿⣿] 108.8MB / 108.8MB Pulling                             7.6s
#  ⠦ pgadmin [⣀⠀⣿⠀⣿⣿⣿⣿⠀⠀⣿⣿⣿⣿⠀] Pulling                                       7.6s
#
#
#
#
#
#
# [+] Running 15/23
#  ⠧ postgres [⣿⣿⣿⣿⣿⣿] 108.8MB / 108.8MB Pulling                             7.7s
#  ⠧ pgadmin [⣀⠀⣿⠀⣿⣿⣿⣿⠀⠀⣿⣿⣿⣿⠀] Pulling                                       7.7s
#
#
#
#
#
#
# [+] Running 16/23
#  ✔ postgres Pulled                                                         7.7s
#  ⠇ pgadmin [⣀⠀⣿⠀⣿⣿⣿⣿⠀⠀⣿⣿⣿⣿⠀] Pulling                                       7.8s
#
#
#
#
#
#
# [+] Running 16/23
#  ✔ postgres Pulled                                                         7.7s
#  ⠏ pgadmin [⣀⠀⣿⠀⣿⣿⣿⣿⠀⠀⣿⣿⣿⣿⠀] Pulling                                       7.9s
#
#
#
#
#
#
# [+] Running 16/23
#  ✔ postgres Pulled                                                         7.7s
#  ⠋ pgadmin [⣀⠀⣿⠀⣿⣿⣿⣿⠀⠀⣿⣿⣿⣿⠀] Pulling                                       8.0s
#
#
#
#
#
#
# [+] Running 16/23
#  ✔ postgres Pulled                                                         7.7s
#  ⠙ pgadmin [⣀⠀⣿⠀⣿⣿⣿⣿⠀⠀⣿⣿⣿⣿⠀] Pulling                                       8.1s
#
#
#
#
#
#
# [+] Running 16/23
#  ✔ postgres Pulled                                                         7.7s
#  ⠹ pgadmin [⣀⠀⣿⠀⣿⣿⣿⣿⠀⠀⣿⣿⣿⣿⠀] Pulling                                       8.2s
#
#
#
#
#
#
# [+] Running 16/23
#  ✔ postgres Pulled                                                         7.7s
# ...
#
# [+] Running 21/23
#  ✔ postgres Pulled                                                         7.7s
#  ⠹ pgadmin [⣿⣿⣿⣿⣿⣿⣿⣿⣿⣷⣿⣿⣿⣿⣿] 171.9MB / 178.2MB Pulling                    58.2s
#
#
#
#
#
#
# [+] Running 21/23
#  ✔ postgres Pulled                                                         7.7s
#  ⠸ pgadmin [⣿⣿⣿⣿⣿⣿⣿⣿⣿⣷⣿⣿⣿⣿⣿] 171.9MB / 178.2MB Pulling                    58.3s
#
#
#
#
#
#
# [+] Running 21/23
#  ✔ postgres Pulled                                                         7.7s
#  ⠼ pgadmin [⣿⣿⣿⣿⣿⣿⣿⣿⣿⣷⣿⣿⣿⣿⣿] 171.9MB / 178.2MB Pulling                    58.4s
#
#
#
#
#
#
# [+] Running 21/23
#  ✔ postgres Pulled                                                         7.7s
#  ⠴ pgadmin [⣿⣿⣿⣿⣿⣿⣿⣿⣿⣷⣿⣿⣿⣿⣿] 172.9MB / 178.2MB Pulling                    58.5s
#
#
#
#
#
#
# [+] Running 21/23
#  ✔ postgres Pulled                                                         7.7s
#  ⠦ pgadmin [⣿⣿⣿⣿⣿⣿⣿⣿⣿⣷⣿⣿⣿⣿⣿] 172.9MB / 178.2MB Pulling                    58.6s
#
#
#
#
#
#
# [+] Running 21/23
#  ✔ postgres Pulled                                                         7.7s
#  ⠧ pgadmin [⣿⣿⣿⣿⣿⣿⣿⣿⣿⣷⣿⣿⣿⣿⣿] 172.9MB / 178.2MB Pulling                    58.7s
#
#
#
#
#
#
# [+] Running 21/23
#  ✔ postgres Pulled                                                         7.7s
#  ⠇ pgadmin [⣿⣿⣿⣿⣿⣿⣿⣿⣿⣷⣿⣿⣿⣿⣿]   174MB / 178.2MB Pulling                    58.8s
#
#
#
#
#
#
# [+] Running 21/23
#  ✔ postgres Pulled                                                         7.7s
#  ⠏ pgadmin [⣿⣿⣿⣿⣿⣿⣿⣿⣿⣷⣿⣿⣿⣿⣿]   174MB / 178.2MB Pulling                    58.9s
#
#
#
#
#
#
# [+] Running 21/23
#  ✔ postgres Pulled                                                         7.7s
#  ⠋ pgadmin [⣿⣿⣿⣿⣿⣿⣿⣿⣿⣷⣿⣿⣿⣿⣿]   174MB / 178.2MB Pulling                    59.0s
#
#
#
#
#
#
# [+] Running 21/23
#  ✔ postgres Pulled                                                         7.7s
#  ⠙ pgadmin [⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿] 175.2MB / 178.2MB Pulling                    59.1s
#
#
#
#
#
#
# [+] Running 21/23
#  ✔ postgres Pulled                                                         7.7s
#  ⠹ pgadmin [⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿] 175.2MB / 178.2MB Pulling                    59.2s
#
#
#
#
#
#
# [+] Running 21/23
#  ✔ postgres Pulled                                                         7.7s
#  ⠸ pgadmin [⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿] 175.2MB / 178.2MB Pulling                    59.3s
#
#
#
#
#
#
# [+] Running 21/23
#  ✔ postgres Pulled                                                         7.7s
#  ⠼ pgadmin [⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿] 175.2MB / 178.2MB Pulling                    59.4s
#
#
#
#
#
#
# [+] Running 21/23
#  ✔ postgres Pulled                                                         7.7s
#  ⠴ pgadmin [⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿] 175.2MB / 178.2MB Pulling                    59.5s
#
#
#
#
#
#
# [+] Running 21/23
#  ✔ postgres Pulled                                                         7.7s
#  ⠦ pgadmin [⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿] 175.2MB / 178.2MB Pulling                    59.6s
#
#
#
#
#
#
# [+] Running 21/23
#  ✔ postgres Pulled                                                         7.7s
#  ⠧ pgadmin [⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿] 175.2MB / 178.2MB Pulling                    59.7s
#
#
#
#
#
#
# [+] Running 21/23
#  ✔ postgres Pulled                                                         7.7s
#  ⠇ pgadmin [⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿] 175.2MB / 178.2MB Pulling                    59.8s
#
#
#
#
#
#
# [+] Running 21/23
#  ✔ postgres Pulled                                                         7.7s
#  ⠏ pgadmin [⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿] 175.2MB / 178.2MB Pulling                    59.9s
#
#
#
#
#
#
# [+] Running 23/23
#  ✔ postgres Pulled                                                         7.7s
#  ✔ pgadmin Pulled                                                         60.0s
#
#
#
#
#
#
# [+] Running 1/2
#  ✔ Network datatalkas_pg-network  Creat...                                 0.0s
#  ⠋ Container pg-database          Creating                                 0.0s
# [+] Running 1/2
#  ✔ Network datatalkas_pg-network  Creat...                                 0.0s
#  ⠙ Container pg-database          Creating                                 0.1s
# [+] Running 1/2
#  ✔ Network datatalkas_pg-network  Creat...                                 0.0s
#  ⠹ Container pg-database          Creating                                 0.2s
# [+] Running 1/2
#  ✔ Network datatalkas_pg-network  Creat...                                 0.0s
#  ⠸ Container pg-database          Creating                                 0.3s
# [+] Running 1/2
#  ✔ Network datatalkas_pg-network  Creat...                                 0.0s
#  ⠼ Container pg-database          Creating                                 0.4s
# [+] Running 1/2
#  ✔ Network datatalkas_pg-network  Creat...                                 0.0s
#  ⠴ Container pg-database          Creating                                 0.5s
# [+] Running 1/2
#  ✔ Network datatalkas_pg-network  Creat...                                 0.0s
#  ⠦ Container pg-database          Creating                                 0.6s
# [+] Running 1/2
#  ✔ Network datatalkas_pg-network  Creat...                                 0.0s
#  ⠧ Container pg-database          Creating                                 0.7s
# [+] Running 2/3
#  ✔ Network datatalkas_pg-network  Creat...                                 0.0s
#  ✔ Container pg-database          Created                                  0.8s
#  ⠋ Container pgadmin              Creating                                 0.1s
# [+] Running 2/3
#  ✔ Network datatalkas_pg-network  Creat...                                 0.0s
#  ⠇ Container pg-database          Starting                                 0.9s
#  ✔ Container pgadmin              Created                                  0.1s
# [+] Running 2/3
#  ✔ Network datatalkas_pg-network  Creat...                                 0.0s
#  ⠏ Container pg-database          Starting                                 1.0s
#  ✔ Container pgadmin              Created                                  0.1s
# [+] Running 2/3
#  ✔ Network datatalkas_pg-network  Creat...                                 0.0s
#  ⠋ Container pg-database          Starting                                 1.1s
#  ✔ Container pgadmin              Created                                  0.1s
# [+] Running 2/3
#  ✔ Network datatalkas_pg-network  Creat...                                 0.0s
#  ✔ Container pg-database          Started                                  1.2s
#  ⠙ Container pgadmin              Starting                                 0.5s
# [+] Running 2/3
#  ✔ Network datatalkas_pg-network  Creat...                                 0.0s
#  ✔ Container pg-database          Started                                  1.2s
#  ⠹ Container pgadmin              Starting                                 0.6s
# [+] Running 3/3
#  ✔ Network datatalkas_pg-network  Creat...                                 0.0s
#  ✔ Container pg-database          Started                                  1.2s
#  ✔ Container pgadmin              Started                                  0.6s

# %%
# !docker build -t zomm-hw:v1 .
# Out:
# 19101.23s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# [+] Building 0.0s (0/1)                                          docker:default
# [+] Building 0.2s (1/2)                                          docker:default
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 474B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.12.8           0.2s
# [+] Building 0.3s (1/2)                                          docker:default
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 474B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.12.8           0.3s
# [+] Building 0.5s (1/2)                                          docker:default
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 474B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.12.8           0.5s
# [+] Building 0.6s (1/2)                                          docker:default
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 474B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.12.8           0.6s
# [+] Building 0.8s (1/2)                                          docker:default
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 474B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.12.8           0.8s
# [+] Building 0.9s (2/2)                                          docker:default
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 474B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.12.8           0.9s
# [+] Building 1.0s (10/11)                                        docker:default
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 474B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.12.8           0.9s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/7] FROM docker.io/library/python:3.12.8@sha256:e74938514dc67ad3ead  0.0s
#  => => resolve docker.io/library/python:3.12.8@sha256:e74938514dc67ad3ead  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 163B                                          0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => CACHED [3/7] RUN apt-get update && apt-get install -y wget && apt-get  0.0s
#  => CACHED [4/7] RUN pip install --no-cache-dir pandas sqlalchemy psycopg  0.0s
#  => CACHED [5/7] RUN mkdir -p /app/archive                                 0.0s
#  => [6/7] COPY ingest1.py /app/ingest1.py                                  0.0s
# [+] Building 1.2s (10/11)                                        docker:default
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 474B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.12.8           0.9s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/7] FROM docker.io/library/python:3.12.8@sha256:e74938514dc67ad3ead  0.0s
#  => => resolve docker.io/library/python:3.12.8@sha256:e74938514dc67ad3ead  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 163B                                          0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => CACHED [3/7] RUN apt-get update && apt-get install -y wget && apt-get  0.0s
#  => CACHED [4/7] RUN pip install --no-cache-dir pandas sqlalchemy psycopg  0.0s
#  => CACHED [5/7] RUN mkdir -p /app/archive                                 0.0s
#  => [6/7] COPY ingest1.py /app/ingest1.py                                  0.0s
#  => [7/7] COPY archive/ /app/archive/                                      0.2s
# [+] Building 1.2s (11/11)                                        docker:default
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 474B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.12.8           0.9s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/7] FROM docker.io/library/python:3.12.8@sha256:e74938514dc67ad3ead  0.0s
#  => => resolve docker.io/library/python:3.12.8@sha256:e74938514dc67ad3ead  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 163B                                          0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => CACHED [3/7] RUN apt-get update && apt-get install -y wget && apt-get  0.0s
#  => CACHED [4/7] RUN pip install --no-cache-dir pandas sqlalchemy psycopg  0.0s
#  => CACHED [5/7] RUN mkdir -p /app/archive                                 0.0s
#  => [6/7] COPY ingest1.py /app/ingest1.py                                  0.0s
#  => [7/7] COPY archive/ /app/archive/                                      0.2s
# [+] Building 1.4s (11/12)                                        docker:default
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 474B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.12.8           0.9s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/7] FROM docker.io/library/python:3.12.8@sha256:e74938514dc67ad3ead  0.0s
#  => => resolve docker.io/library/python:3.12.8@sha256:e74938514dc67ad3ead  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 163B                                          0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => CACHED [3/7] RUN apt-get update && apt-get install -y wget && apt-get  0.0s
#  => CACHED [4/7] RUN pip install --no-cache-dir pandas sqlalchemy psycopg  0.0s
#  => CACHED [5/7] RUN mkdir -p /app/archive                                 0.0s
#  => [6/7] COPY ingest1.py /app/ingest1.py                                  0.0s
#  => [7/7] COPY archive/ /app/archive/                                      0.2s
#  => exporting to image                                                     0.2s
#  => => exporting layers                                                    0.2s
# [+] Building 1.5s (11/12)                                        docker:default
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 474B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.12.8           0.9s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/7] FROM docker.io/library/python:3.12.8@sha256:e74938514dc67ad3ead  0.0s
#  => => resolve docker.io/library/python:3.12.8@sha256:e74938514dc67ad3ead  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 163B                                          0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => CACHED [3/7] RUN apt-get update && apt-get install -y wget && apt-get  0.0s
#  => CACHED [4/7] RUN pip install --no-cache-dir pandas sqlalchemy psycopg  0.0s
#  => CACHED [5/7] RUN mkdir -p /app/archive                                 0.0s
#  => [6/7] COPY ingest1.py /app/ingest1.py                                  0.0s
#  => [7/7] COPY archive/ /app/archive/                                      0.2s
#  => exporting to image                                                     0.3s
#  => => exporting layers                                                    0.3s
# [+] Building 1.7s (11/12)                                        docker:default
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 474B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.12.8           0.9s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/7] FROM docker.io/library/python:3.12.8@sha256:e74938514dc67ad3ead  0.0s
#  => => resolve docker.io/library/python:3.12.8@sha256:e74938514dc67ad3ead  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 163B                                          0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => CACHED [3/7] RUN apt-get update && apt-get install -y wget && apt-get  0.0s
#  => CACHED [4/7] RUN pip install --no-cache-dir pandas sqlalchemy psycopg  0.0s
#  => CACHED [5/7] RUN mkdir -p /app/archive                                 0.0s
#  => [6/7] COPY ingest1.py /app/ingest1.py                                  0.0s
#  => [7/7] COPY archive/ /app/archive/                                      0.2s
#  => exporting to image                                                     0.5s
#  => => exporting layers                                                    0.5s
# [+] Building 1.8s (11/12)                                        docker:default
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 474B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.12.8           0.9s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/7] FROM docker.io/library/python:3.12.8@sha256:e74938514dc67ad3ead  0.0s
#  => => resolve docker.io/library/python:3.12.8@sha256:e74938514dc67ad3ead  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 163B                                          0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => CACHED [3/7] RUN apt-get update && apt-get install -y wget && apt-get  0.0s
#  => CACHED [4/7] RUN pip install --no-cache-dir pandas sqlalchemy psycopg  0.0s
#  => CACHED [5/7] RUN mkdir -p /app/archive                                 0.0s
#  => [6/7] COPY ingest1.py /app/ingest1.py                                  0.0s
#  => [7/7] COPY archive/ /app/archive/                                      0.2s
#  => exporting to image                                                     0.6s
#  => => exporting layers                                                    0.6s
# [+] Building 2.0s (11/12)                                        docker:default
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 474B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.12.8           0.9s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/7] FROM docker.io/library/python:3.12.8@sha256:e74938514dc67ad3ead  0.0s
#  => => resolve docker.io/library/python:3.12.8@sha256:e74938514dc67ad3ead  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 163B                                          0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => CACHED [3/7] RUN apt-get update && apt-get install -y wget && apt-get  0.0s
#  => CACHED [4/7] RUN pip install --no-cache-dir pandas sqlalchemy psycopg  0.0s
#  => CACHED [5/7] RUN mkdir -p /app/archive                                 0.0s
#  => [6/7] COPY ingest1.py /app/ingest1.py                                  0.0s
#  => [7/7] COPY archive/ /app/archive/                                      0.2s
#  => exporting to image                                                     0.8s
#  => => exporting layers                                                    0.8s
# [+] Building 2.1s (11/12)                                        docker:default
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 474B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.12.8           0.9s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/7] FROM docker.io/library/python:3.12.8@sha256:e74938514dc67ad3ead  0.0s
#  => => resolve docker.io/library/python:3.12.8@sha256:e74938514dc67ad3ead  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 163B                                          0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => CACHED [3/7] RUN apt-get update && apt-get install -y wget && apt-get  0.0s
#  => CACHED [4/7] RUN pip install --no-cache-dir pandas sqlalchemy psycopg  0.0s
#  => CACHED [5/7] RUN mkdir -p /app/archive                                 0.0s
#  => [6/7] COPY ingest1.py /app/ingest1.py                                  0.0s
#  => [7/7] COPY archive/ /app/archive/                                      0.2s
#  => exporting to image                                                     0.9s
#  => => exporting layers                                                    0.9s
# [+] Building 2.3s (11/12)                                        docker:default
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 474B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.12.8           0.9s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/7] FROM docker.io/library/python:3.12.8@sha256:e74938514dc67ad3ead  0.0s
#  => => resolve docker.io/library/python:3.12.8@sha256:e74938514dc67ad3ead  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 163B                                          0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => CACHED [3/7] RUN apt-get update && apt-get install -y wget && apt-get  0.0s
#  => CACHED [4/7] RUN pip install --no-cache-dir pandas sqlalchemy psycopg  0.0s
#  => CACHED [5/7] RUN mkdir -p /app/archive                                 0.0s
#  => [6/7] COPY ingest1.py /app/ingest1.py                                  0.0s
#  => [7/7] COPY archive/ /app/archive/                                      0.2s
#  => exporting to image                                                     1.1s
#  => => exporting layers                                                    1.1s
# [+] Building 2.4s (11/12)                                        docker:default
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 474B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.12.8           0.9s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/7] FROM docker.io/library/python:3.12.8@sha256:e74938514dc67ad3ead  0.0s
#  => => resolve docker.io/library/python:3.12.8@sha256:e74938514dc67ad3ead  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 163B                                          0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => CACHED [3/7] RUN apt-get update && apt-get install -y wget && apt-get  0.0s
#  => CACHED [4/7] RUN pip install --no-cache-dir pandas sqlalchemy psycopg  0.0s
#  => CACHED [5/7] RUN mkdir -p /app/archive                                 0.0s
#  => [6/7] COPY ingest1.py /app/ingest1.py                                  0.0s
#  => [7/7] COPY archive/ /app/archive/                                      0.2s
#  => exporting to image                                                     1.2s
#  => => exporting layers                                                    1.2s
# [+] Building 2.6s (11/12)                                        docker:default
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 474B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.12.8           0.9s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/7] FROM docker.io/library/python:3.12.8@sha256:e74938514dc67ad3ead  0.0s
#  => => resolve docker.io/library/python:3.12.8@sha256:e74938514dc67ad3ead  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 163B                                          0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => CACHED [3/7] RUN apt-get update && apt-get install -y wget && apt-get  0.0s
#  => CACHED [4/7] RUN pip install --no-cache-dir pandas sqlalchemy psycopg  0.0s
#  => CACHED [5/7] RUN mkdir -p /app/archive                                 0.0s
#  => [6/7] COPY ingest1.py /app/ingest1.py                                  0.0s
#  => [7/7] COPY archive/ /app/archive/                                      0.2s
#  => exporting to image                                                     1.4s
#  => => exporting layers                                                    1.4s
# [+] Building 2.6s (11/12)                                        docker:default
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 474B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.12.8           0.9s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/7] FROM docker.io/library/python:3.12.8@sha256:e74938514dc67ad3ead  0.0s
#  => => resolve docker.io/library/python:3.12.8@sha256:e74938514dc67ad3ead  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 163B                                          0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => CACHED [3/7] RUN apt-get update && apt-get install -y wget && apt-get  0.0s
#  => CACHED [4/7] RUN pip install --no-cache-dir pandas sqlalchemy psycopg  0.0s
#  => CACHED [5/7] RUN mkdir -p /app/archive                                 0.0s
#  => [6/7] COPY ingest1.py /app/ingest1.py                                  0.0s
#  => [7/7] COPY archive/ /app/archive/                                      0.2s
#  => exporting to image                                                     1.4s
#  => => exporting layers                                                    1.4s
# [+] Building 2.7s (11/12)                                        docker:default
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 474B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.12.8           0.9s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/7] FROM docker.io/library/python:3.12.8@sha256:e74938514dc67ad3ead  0.0s
#  => => resolve docker.io/library/python:3.12.8@sha256:e74938514dc67ad3ead  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 163B                                          0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => CACHED [3/7] RUN apt-get update && apt-get install -y wget && apt-get  0.0s
#  => CACHED [4/7] RUN pip install --no-cache-dir pandas sqlalchemy psycopg  0.0s
#  => CACHED [5/7] RUN mkdir -p /app/archive                                 0.0s
#  => [6/7] COPY ingest1.py /app/ingest1.py                                  0.0s
#  => [7/7] COPY archive/ /app/archive/                                      0.2s
#  => exporting to image                                                     1.5s
#  => => exporting layers                                                    1.4s
#  => => exporting manifest sha256:1e1599ec23069a5b75c1636488bc0dbac79d1bd1  0.0s
#  => => exporting config sha256:25f29e6b2862cc6a279a71ab0214b706ef2a7aa277  0.0s
#  => => exporting attestation manifest sha256:dc21a0a4a62b4c1503eb2e35e5f4  0.0s
#  => => exporting manifest list sha256:660c615f333f75f3ccf10ef1cf4ef1130e1  0.0s
#  => => naming to docker.io/library/zomm-hw:v1                              0.0s
# [+] Building 2.9s (11/12)                                        docker:default
#  => => transferring dockerfile: 474B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.12.8           0.9s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/7] FROM docker.io/library/python:3.12.8@sha256:e74938514dc67ad3ead  0.0s
#  => => resolve docker.io/library/python:3.12.8@sha256:e74938514dc67ad3ead  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 163B                                          0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => CACHED [3/7] RUN apt-get update && apt-get install -y wget && apt-get  0.0s
#  => CACHED [4/7] RUN pip install --no-cache-dir pandas sqlalchemy psycopg  0.0s
#  => CACHED [5/7] RUN mkdir -p /app/archive                                 0.0s
#  => [6/7] COPY ingest1.py /app/ingest1.py                                  0.0s
#  => [7/7] COPY archive/ /app/archive/                                      0.2s
#  => exporting to image                                                     1.7s
#  => => exporting layers                                                    1.4s
#  => => exporting manifest sha256:1e1599ec23069a5b75c1636488bc0dbac79d1bd1  0.0s
#  => => exporting config sha256:25f29e6b2862cc6a279a71ab0214b706ef2a7aa277  0.0s
#  => => exporting attestation manifest sha256:dc21a0a4a62b4c1503eb2e35e5f4  0.0s
#  => => exporting manifest list sha256:660c615f333f75f3ccf10ef1cf4ef1130e1  0.0s
#  => => naming to docker.io/library/zomm-hw:v1                              0.0s
#  => => unpacking to docker.io/library/zomm-hw:v1                           0.2s
# [+] Building 3.0s (11/12)                                        docker:default
#  => => transferring dockerfile: 474B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.12.8           0.9s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/7] FROM docker.io/library/python:3.12.8@sha256:e74938514dc67ad3ead  0.0s
#  => => resolve docker.io/library/python:3.12.8@sha256:e74938514dc67ad3ead  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 163B                                          0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => CACHED [3/7] RUN apt-get update && apt-get install -y wget && apt-get  0.0s
#  => CACHED [4/7] RUN pip install --no-cache-dir pandas sqlalchemy psycopg  0.0s
#  => CACHED [5/7] RUN mkdir -p /app/archive                                 0.0s
#  => [6/7] COPY ingest1.py /app/ingest1.py                                  0.0s
#  => [7/7] COPY archive/ /app/archive/                                      0.2s
#  => exporting to image                                                     1.8s
#  => => exporting layers                                                    1.4s
#  => => exporting manifest sha256:1e1599ec23069a5b75c1636488bc0dbac79d1bd1  0.0s
#  => => exporting config sha256:25f29e6b2862cc6a279a71ab0214b706ef2a7aa277  0.0s
#  => => exporting attestation manifest sha256:dc21a0a4a62b4c1503eb2e35e5f4  0.0s
#  => => exporting manifest list sha256:660c615f333f75f3ccf10ef1cf4ef1130e1  0.0s
#  => => naming to docker.io/library/zomm-hw:v1                              0.0s
#  => => unpacking to docker.io/library/zomm-hw:v1                           0.3s
# [+] Building 3.2s (11/12)                                        docker:default
#  => => transferring dockerfile: 474B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.12.8           0.9s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/7] FROM docker.io/library/python:3.12.8@sha256:e74938514dc67ad3ead  0.0s
#  => => resolve docker.io/library/python:3.12.8@sha256:e74938514dc67ad3ead  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 163B                                          0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => CACHED [3/7] RUN apt-get update && apt-get install -y wget && apt-get  0.0s
#  => CACHED [4/7] RUN pip install --no-cache-dir pandas sqlalchemy psycopg  0.0s
#  => CACHED [5/7] RUN mkdir -p /app/archive                                 0.0s
#  => [6/7] COPY ingest1.py /app/ingest1.py                                  0.0s
#  => [7/7] COPY archive/ /app/archive/                                      0.2s
#  => exporting to image                                                     2.0s
#  => => exporting layers                                                    1.4s
#  => => exporting manifest sha256:1e1599ec23069a5b75c1636488bc0dbac79d1bd1  0.0s
#  => => exporting config sha256:25f29e6b2862cc6a279a71ab0214b706ef2a7aa277  0.0s
#  => => exporting attestation manifest sha256:dc21a0a4a62b4c1503eb2e35e5f4  0.0s
#  => => exporting manifest list sha256:660c615f333f75f3ccf10ef1cf4ef1130e1  0.0s
#  => => naming to docker.io/library/zomm-hw:v1                              0.0s
#  => => unpacking to docker.io/library/zomm-hw:v1                           0.5s
# [+] Building 3.3s (11/12)                                        docker:default
#  => => transferring dockerfile: 474B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.12.8           0.9s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/7] FROM docker.io/library/python:3.12.8@sha256:e74938514dc67ad3ead  0.0s
#  => => resolve docker.io/library/python:3.12.8@sha256:e74938514dc67ad3ead  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 163B                                          0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => CACHED [3/7] RUN apt-get update && apt-get install -y wget && apt-get  0.0s
#  => CACHED [4/7] RUN pip install --no-cache-dir pandas sqlalchemy psycopg  0.0s
#  => CACHED [5/7] RUN mkdir -p /app/archive                                 0.0s
#  => [6/7] COPY ingest1.py /app/ingest1.py                                  0.0s
#  => [7/7] COPY archive/ /app/archive/                                      0.2s
#  => exporting to image                                                     2.1s
#  => => exporting layers                                                    1.4s
#  => => exporting manifest sha256:1e1599ec23069a5b75c1636488bc0dbac79d1bd1  0.0s
#  => => exporting config sha256:25f29e6b2862cc6a279a71ab0214b706ef2a7aa277  0.0s
#  => => exporting attestation manifest sha256:dc21a0a4a62b4c1503eb2e35e5f4  0.0s
#  => => exporting manifest list sha256:660c615f333f75f3ccf10ef1cf4ef1130e1  0.0s
#  => => naming to docker.io/library/zomm-hw:v1                              0.0s
#  => => unpacking to docker.io/library/zomm-hw:v1                           0.6s
# [+] Building 3.5s (11/12)                                        docker:default
#  => => transferring dockerfile: 474B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.12.8           0.9s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/7] FROM docker.io/library/python:3.12.8@sha256:e74938514dc67ad3ead  0.0s
#  => => resolve docker.io/library/python:3.12.8@sha256:e74938514dc67ad3ead  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 163B                                          0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => CACHED [3/7] RUN apt-get update && apt-get install -y wget && apt-get  0.0s
#  => CACHED [4/7] RUN pip install --no-cache-dir pandas sqlalchemy psycopg  0.0s
#  => CACHED [5/7] RUN mkdir -p /app/archive                                 0.0s
#  => [6/7] COPY ingest1.py /app/ingest1.py                                  0.0s
#  => [7/7] COPY archive/ /app/archive/                                      0.2s
#  => exporting to image                                                     2.3s
#  => => exporting layers                                                    1.4s
#  => => exporting manifest sha256:1e1599ec23069a5b75c1636488bc0dbac79d1bd1  0.0s
#  => => exporting config sha256:25f29e6b2862cc6a279a71ab0214b706ef2a7aa277  0.0s
#  => => exporting attestation manifest sha256:dc21a0a4a62b4c1503eb2e35e5f4  0.0s
#  => => exporting manifest list sha256:660c615f333f75f3ccf10ef1cf4ef1130e1  0.0s
#  => => naming to docker.io/library/zomm-hw:v1                              0.0s
#  => => unpacking to docker.io/library/zomm-hw:v1                           0.8s
# [+] Building 3.6s (11/12)                                        docker:default
#  => => transferring dockerfile: 474B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.12.8           0.9s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/7] FROM docker.io/library/python:3.12.8@sha256:e74938514dc67ad3ead  0.0s
#  => => resolve docker.io/library/python:3.12.8@sha256:e74938514dc67ad3ead  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 163B                                          0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => CACHED [3/7] RUN apt-get update && apt-get install -y wget && apt-get  0.0s
#  => CACHED [4/7] RUN pip install --no-cache-dir pandas sqlalchemy psycopg  0.0s
#  => CACHED [5/7] RUN mkdir -p /app/archive                                 0.0s
#  => [6/7] COPY ingest1.py /app/ingest1.py                                  0.0s
#  => [7/7] COPY archive/ /app/archive/                                      0.2s
#  => exporting to image                                                     2.4s
#  => => exporting layers                                                    1.4s
#  => => exporting manifest sha256:1e1599ec23069a5b75c1636488bc0dbac79d1bd1  0.0s
#  => => exporting config sha256:25f29e6b2862cc6a279a71ab0214b706ef2a7aa277  0.0s
#  => => exporting attestation manifest sha256:dc21a0a4a62b4c1503eb2e35e5f4  0.0s
#  => => exporting manifest list sha256:660c615f333f75f3ccf10ef1cf4ef1130e1  0.0s
#  => => naming to docker.io/library/zomm-hw:v1                              0.0s
#  => => unpacking to docker.io/library/zomm-hw:v1                           0.9s
# [+] Building 3.8s (11/12)                                        docker:default
#  => => transferring dockerfile: 474B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.12.8           0.9s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/7] FROM docker.io/library/python:3.12.8@sha256:e74938514dc67ad3ead  0.0s
#  => => resolve docker.io/library/python:3.12.8@sha256:e74938514dc67ad3ead  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 163B                                          0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => CACHED [3/7] RUN apt-get update && apt-get install -y wget && apt-get  0.0s
#  => CACHED [4/7] RUN pip install --no-cache-dir pandas sqlalchemy psycopg  0.0s
#  => CACHED [5/7] RUN mkdir -p /app/archive                                 0.0s
#  => [6/7] COPY ingest1.py /app/ingest1.py                                  0.0s
#  => [7/7] COPY archive/ /app/archive/                                      0.2s
#  => exporting to image                                                     2.6s
#  => => exporting layers                                                    1.4s
#  => => exporting manifest sha256:1e1599ec23069a5b75c1636488bc0dbac79d1bd1  0.0s
#  => => exporting config sha256:25f29e6b2862cc6a279a71ab0214b706ef2a7aa277  0.0s
#  => => exporting attestation manifest sha256:dc21a0a4a62b4c1503eb2e35e5f4  0.0s
#  => => exporting manifest list sha256:660c615f333f75f3ccf10ef1cf4ef1130e1  0.0s
#  => => naming to docker.io/library/zomm-hw:v1                              0.0s
#  => => unpacking to docker.io/library/zomm-hw:v1                           1.1s
# [+] Building 3.9s (11/12)                                        docker:default
#  => => transferring dockerfile: 474B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.12.8           0.9s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/7] FROM docker.io/library/python:3.12.8@sha256:e74938514dc67ad3ead  0.0s
#  => => resolve docker.io/library/python:3.12.8@sha256:e74938514dc67ad3ead  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 163B                                          0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => CACHED [3/7] RUN apt-get update && apt-get install -y wget && apt-get  0.0s
#  => CACHED [4/7] RUN pip install --no-cache-dir pandas sqlalchemy psycopg  0.0s
#  => CACHED [5/7] RUN mkdir -p /app/archive                                 0.0s
#  => [6/7] COPY ingest1.py /app/ingest1.py                                  0.0s
#  => [7/7] COPY archive/ /app/archive/                                      0.2s
#  => exporting to image                                                     2.7s
#  => => exporting layers                                                    1.4s
#  => => exporting manifest sha256:1e1599ec23069a5b75c1636488bc0dbac79d1bd1  0.0s
#  => => exporting config sha256:25f29e6b2862cc6a279a71ab0214b706ef2a7aa277  0.0s
#  => => exporting attestation manifest sha256:dc21a0a4a62b4c1503eb2e35e5f4  0.0s
#  => => exporting manifest list sha256:660c615f333f75f3ccf10ef1cf4ef1130e1  0.0s
#  => => naming to docker.io/library/zomm-hw:v1                              0.0s
#  => => unpacking to docker.io/library/zomm-hw:v1                           1.2s
# [+] Building 4.1s (11/12)                                        docker:default
#  => => transferring dockerfile: 474B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.12.8           0.9s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/7] FROM docker.io/library/python:3.12.8@sha256:e74938514dc67ad3ead  0.0s
#  => => resolve docker.io/library/python:3.12.8@sha256:e74938514dc67ad3ead  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 163B                                          0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => CACHED [3/7] RUN apt-get update && apt-get install -y wget && apt-get  0.0s
#  => CACHED [4/7] RUN pip install --no-cache-dir pandas sqlalchemy psycopg  0.0s
#  => CACHED [5/7] RUN mkdir -p /app/archive                                 0.0s
#  => [6/7] COPY ingest1.py /app/ingest1.py                                  0.0s
#  => [7/7] COPY archive/ /app/archive/                                      0.2s
#  => exporting to image                                                     2.9s
#  => => exporting layers                                                    1.4s
#  => => exporting manifest sha256:1e1599ec23069a5b75c1636488bc0dbac79d1bd1  0.0s
#  => => exporting config sha256:25f29e6b2862cc6a279a71ab0214b706ef2a7aa277  0.0s
#  => => exporting attestation manifest sha256:dc21a0a4a62b4c1503eb2e35e5f4  0.0s
#  => => exporting manifest list sha256:660c615f333f75f3ccf10ef1cf4ef1130e1  0.0s
#  => => naming to docker.io/library/zomm-hw:v1                              0.0s
#  => => unpacking to docker.io/library/zomm-hw:v1                           1.4s
# [+] Building 4.2s (11/12)                                        docker:default
#  => => transferring dockerfile: 474B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.12.8           0.9s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/7] FROM docker.io/library/python:3.12.8@sha256:e74938514dc67ad3ead  0.0s
#  => => resolve docker.io/library/python:3.12.8@sha256:e74938514dc67ad3ead  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 163B                                          0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => CACHED [3/7] RUN apt-get update && apt-get install -y wget && apt-get  0.0s
#  => CACHED [4/7] RUN pip install --no-cache-dir pandas sqlalchemy psycopg  0.0s
#  => CACHED [5/7] RUN mkdir -p /app/archive                                 0.0s
#  => [6/7] COPY ingest1.py /app/ingest1.py                                  0.0s
#  => [7/7] COPY archive/ /app/archive/                                      0.2s
#  => exporting to image                                                     3.0s
#  => => exporting layers                                                    1.4s
#  => => exporting manifest sha256:1e1599ec23069a5b75c1636488bc0dbac79d1bd1  0.0s
#  => => exporting config sha256:25f29e6b2862cc6a279a71ab0214b706ef2a7aa277  0.0s
#  => => exporting attestation manifest sha256:dc21a0a4a62b4c1503eb2e35e5f4  0.0s
#  => => exporting manifest list sha256:660c615f333f75f3ccf10ef1cf4ef1130e1  0.0s
#  => => naming to docker.io/library/zomm-hw:v1                              0.0s
#  => => unpacking to docker.io/library/zomm-hw:v1                           1.5s
# [+] Building 4.3s (12/12) FINISHED                               docker:default
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 474B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.12.8           0.9s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/7] FROM docker.io/library/python:3.12.8@sha256:e74938514dc67ad3ead  0.0s
#  => => resolve docker.io/library/python:3.12.8@sha256:e74938514dc67ad3ead  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 163B                                          0.0s
#  => CACHED [2/7] WORKDIR /app                                              0.0s
#  => CACHED [3/7] RUN apt-get update && apt-get install -y wget && apt-get  0.0s
#  => CACHED [4/7] RUN pip install --no-cache-dir pandas sqlalchemy psycopg  0.0s
#  => CACHED [5/7] RUN mkdir -p /app/archive                                 0.0s
#  => [6/7] COPY ingest1.py /app/ingest1.py                                  0.0s
#  => [7/7] COPY archive/ /app/archive/                                      0.2s
#  => exporting to image                                                     3.0s
#  => => exporting layers                                                    1.4s
#  => => exporting manifest sha256:1e1599ec23069a5b75c1636488bc0dbac79d1bd1  0.0s
#  => => exporting config sha256:25f29e6b2862cc6a279a71ab0214b706ef2a7aa277  0.0s
#  => => exporting attestation manifest sha256:dc21a0a4a62b4c1503eb2e35e5f4  0.0s
#  => => exporting manifest list sha256:660c615f333f75f3ccf10ef1cf4ef1130e1  0.0s
#  => => naming to docker.io/library/zomm-hw:v1                              0.0s
#  => => unpacking to docker.io/library/zomm-hw:v1                           1.5s

# %%
# !docker run -it --network=datatalkas_pg-network zomm-hw:v1  \
                    --user=root \
                    --password=root \
                    --db=ny_taxi \
                    --host=pg-database \
                    --port=5432 \
                    --table_name=hw-green \
                    --file_url=https://github.com/DataTalksClub/nyc-tlc-data/releases/download/green/green_tripdata_2019-10.csv.gz
# Out:
# 19123.14s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# 📥 Downloading file from https://github.com/DataTalksClub/nyc-tlc-data/releases/download/green/green_tripdata_2019-10.csv.gz
# --2025-11-11 12:30:48--  https://github.com/DataTalksClub/nyc-tlc-data/releases/download/green/green_tripdata_2019-10.csv.gz
# Resolving github.com (github.com)... 20.207.73.82
# Connecting to github.com (github.com)|20.207.73.82|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://release-assets.githubusercontent.com/github-production-release-asset/513814948/ea580e9e-555c-4bd0-ae73-43051d8e7c0b?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-11-11T13%3A14%3A35Z&rscd=attachment%3B+filename%3Dgreen_tripdata_2019-10.csv.gz&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-11-11T12%3A13%3A39Z&ske=2025-11-11T13%3A14%3A35Z&sks=b&skv=2018-11-09&sig=akyHGvhTdVFjkRJESIJGEThq3DEi%2BPZ%2FLU69f6y3iX8%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc2Mjg2NDU1MCwibmJmIjoxNzYyODY0MjUwLCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.eahdb-hySO1LYritVwit2p0fPc2djO1C_mseMB86QgI&response-content-disposition=attachment%3B%20filename%3Dgreen_tripdata_2019-10.csv.gz&response-content-type=application%2Foctet-stream [following]
# --2025-11-11 12:30:49--  https://release-assets.githubusercontent.com/github-production-release-asset/513814948/ea580e9e-555c-4bd0-ae73-43051d8e7c0b?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-11-11T13%3A14%3A35Z&rscd=attachment%3B+filename%3Dgreen_tripdata_2019-10.csv.gz&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-11-11T12%3A13%3A39Z&ske=2025-11-11T13%3A14%3A35Z&sks=b&skv=2018-11-09&sig=akyHGvhTdVFjkRJESIJGEThq3DEi%2BPZ%2FLU69f6y3iX8%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc2Mjg2NDU1MCwibmJmIjoxNzYyODY0MjUwLCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.eahdb-hySO1LYritVwit2p0fPc2djO1C_mseMB86QgI&response-content-disposition=attachment%3B%20filename%3Dgreen_tripdata_2019-10.csv.gz&response-content-type=application%2Foctet-stream
# Resolving release-assets.githubusercontent.com (release-assets.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to release-assets.githubusercontent.com (release-assets.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8262584 (7.9M) [application/octet-stream]
# Saving to: ‘green_tripdata_2019-10.csv.gz’
#
# green_tripdata_2019 100%[===================>]   7.88M  4.91MB/s    in 1.6s
#
# 2025-11-11 12:30:51 (4.91 MB/s) - ‘green_tripdata_2019-10.csv.gz’ saved [8262584/8262584]
#
# ⬇️  Downloading: https://github.com/DataTalksClub/nyc-tlc-data/releases/download/green/green_tripdata_2019-10.csv.gz
# 🗜️ Extracting compressed file: green_tripdata_2019-10.csv.gz → green_tripdata_2019-10.csv
# ✅ Extraction complete.
# 🚀 Connecting to Postgres: pg-database:5432/ny_taxi
# Connected to  <sqlalchemy.engine.base.Connection object at 0x7f227b9cc0b0>  postgress server
# Traceback (most recent call last):
#   File "/app/ingest1.py", line 90, in <module>
#     main(args)
#   File "/app/ingest1.py", line 47, in main
#     print(f"📄 Reading data from {csv_file}")
#                                   ^^^^^^^^
# UnboundLocalError: cannot access local variable 'csv_file' where it is not associated with a value

# %%
# !docker run -it --network=datatalkas_pg-network zomm-hw:v1  \
                    --user=root \
                    --password=root \
                    --db=ny_taxi \
                    --host=pg-database \
                    --port=5432 \
                    --table_name=taxi_zone_lookup \
                    --file_url=https://github.com/DataTalksClub/nyc-tlc-data/releases/download/misc/taxi_zone_lookup.csv
# Out:
# 19900.59s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# 📥 Downloading file from https://github.com/DataTalksClub/nyc-tlc-data/releases/download/misc/taxi_zone_lookup.csv
# --2025-11-11 12:43:46--  https://github.com/DataTalksClub/nyc-tlc-data/releases/download/misc/taxi_zone_lookup.csv
# Resolving github.com (github.com)... 20.207.73.82
# Connecting to github.com (github.com)|20.207.73.82|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://release-assets.githubusercontent.com/github-production-release-asset/513814948/5a2cc2f5-b4cd-4584-9c62-a6ea97ed0e6a?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-11-11T13%3A39%3A49Z&rscd=attachment%3B+filename%3Dtaxi_zone_lookup.csv&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-11-11T12%3A39%3A05Z&ske=2025-11-11T13%3A39%3A49Z&sks=b&skv=2018-11-09&sig=UloaOhiRChN%2B4oYIzfdB85ML8OqmvQycmBlXrrfxGiU%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc2Mjg2NTMyOSwibmJmIjoxNzYyODY1MDI5LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.U6ZKs_uy1f_q6jmx44p0z5Y1jiW3fGXfa5GcJDkBWow&response-content-disposition=attachment%3B%20filename%3Dtaxi_zone_lookup.csv&response-content-type=application%2Foctet-stream [following]
# --2025-11-11 12:43:46--  https://release-assets.githubusercontent.com/github-production-release-asset/513814948/5a2cc2f5-b4cd-4584-9c62-a6ea97ed0e6a?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-11-11T13%3A39%3A49Z&rscd=attachment%3B+filename%3Dtaxi_zone_lookup.csv&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-11-11T12%3A39%3A05Z&ske=2025-11-11T13%3A39%3A49Z&sks=b&skv=2018-11-09&sig=UloaOhiRChN%2B4oYIzfdB85ML8OqmvQycmBlXrrfxGiU%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc2Mjg2NTMyOSwibmJmIjoxNzYyODY1MDI5LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.U6ZKs_uy1f_q6jmx44p0z5Y1jiW3fGXfa5GcJDkBWow&response-content-disposition=attachment%3B%20filename%3Dtaxi_zone_lookup.csv&response-content-type=application%2Foctet-stream
# Resolving release-assets.githubusercontent.com (release-assets.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to release-assets.githubusercontent.com (release-assets.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12322 (12K) [application/octet-stream]
# Saving to: ‘taxi_zone_lookup.csv’
#
# taxi_zone_lookup.cs 100%[===================>]  12.03K  --.-KB/s    in 0.008s
#
# 2025-11-11 12:43:47 (1.57 MB/s) - ‘taxi_zone_lookup.csv’ saved [12322/12322]
#
# ⬇️  Downloading: https://github.com/DataTalksClub/nyc-tlc-data/releases/download/misc/taxi_zone_lookup.csv
# ✅ File is not compressed, proceeding normally.
# 🚀 Connecting to Postgres: pg-database:5432/ny_taxi
# Connected to  <sqlalchemy.engine.base.Connection object at 0x7efde2f87bc0>  postgress server
# 📄 Reading data from taxi_zone_lookup.csv
# 🏁 Ingestion complete — no more chunks to process.

# %%
import pandas as pd 

query = """
SELECT table_name
FROM information_schema.tables
WHERE table_schema = 'public';
"""
table_names = pd.read_sql(query, con=engine)
table_names
# Out:
#          table_name
# 0          hw_green
# 1  taxi_zone_lookup
# 2          hw-green

# %%
query = "SELECT count(1) FROM hw_green;"
tables = pd.read_sql(query, con=engine)
tables
# Out:
#     count
# 0  376386

# %%
query = "SELECT * FROM hw_green LIMIT 100;"
tables = pd.read_sql(query, con=engine)
tables
# Out:
#    index  VendorID lpep_pickup_datetime lpep_dropoff_datetime  \
# 0   None         2  2019-10-08 15:30:23   2019-10-08 15:37:34
# 1   None         2  2019-10-08 15:17:48   2019-10-08 15:26:33
# 2   None         2  2019-10-08 16:01:41   2019-10-08 16:29:08
# 3   None         1  2019-10-08 15:54:49   2019-10-08 15:59:37
# 4   None         2  2019-10-08 15:14:39   2019-10-08 15:30:24
# ..   ...       ...                  ...                   ...
# 95  None         2  2019-10-08 15:52:59   2019-10-08 16:02:00
# 96  None         2  2019-10-08 15:09:29   2019-10-08 15:18:55
# 97  None         2  2019-10-08 15:30:30   2019-10-08 15:35:33
# 98  None         1  2019-10-08 15:55:01   2019-10-08 16:11:09
# 99  None         2  2019-10-08 15:28:51   2019-10-08 15:45:15
#
#    store_and_fwd_flag  RatecodeID  PULocationID  DOLocationID  \
# 0                   N           1            65            66
# 1                   N           1           226           260
# 2                   N           1           226           161
# 3                   N           1           181           181
# 4                   N           1           179           223
# ..                ...         ...           ...           ...
# 95                  N           1            75            41
# 96                  N           1            75           238
# 97                  N           1            75            43
# 98                  N           1           189            17
# 99                  N           1            65            17
#
#     passenger_count  trip_distance  ...  extra  mta_tax  tip_amount  \
# 0                 1           0.95  ...    0.0      0.5        2.19
# 1                 1           1.69  ...    0.0      0.5        1.20
# 2                 1           3.41  ...    0.0      0.5        4.31
# 3                 1           0.60  ...    1.0      0.5        0.00
# 4                 1           1.20  ...    0.0      0.5        0.00
# ..              ...            ...  ...    ...      ...         ...
# 95                1           1.06  ...    0.0      0.5        1.00
# 96                1           0.98  ...    0.0      0.5        1.50
# 97                1           0.99  ...    0.0      0.5        0.00
# 98                1           2.50  ...    1.0      0.5        0.00
# 99                1           2.18  ...    0.0      0.5        3.08
#
#     tolls_amount  ehail_fee improvement_surcharge  total_amount  payment_type  \
# 0            0.0       None                   0.3          9.49             1
# 1            0.0       None                   0.3         10.00             1
# 2            0.0       None                   0.3         25.86             1
# 3            0.0       None                   0.3          6.80             2
# 4            0.0       None                   0.3         11.30             2
# ..           ...        ...                   ...           ...           ...
# 95           0.0       None                   0.3          9.30             1
# 96           0.0       None                   0.3         10.30             1
# 97           0.0       None                   0.3          6.30             2
# 98           0.0       None                   0.3         14.30             1
# 99           0.0       None                   0.3         15.38             1
#
#     trip_type  congestion_surcharge
# 0         1.0                  0.00
# 1         1.0                  0.00
# 2         1.0                  2.75
# 3         1.0                  0.00
# 4         1.0                  0.00
# ..        ...                   ...
# 95        1.0                  0.00
# 96        1.0                  0.00
# 97        1.0                  0.00
# 98        1.0                  0.00
# 99        1.0                  0.00
#
# [100 rows x 21 columns]

# %%
query = """
SELECT 
    column_name, 
    data_type, 
    is_nullable
FROM information_schema.columns
WHERE table_name = 'hw_green';
"""
columns_info = pd.read_sql(query, con=engine)
columns_info
# Out:
#               column_name         data_type is_nullable
# 0                   index            bigint         YES
# 1                VendorID            bigint         YES
# 2    lpep_pickup_datetime              text         YES
# 3   lpep_dropoff_datetime              text         YES
# 4      store_and_fwd_flag              text         YES
# 5              RatecodeID            bigint         YES
# 6            PULocationID            bigint         YES
# 7            DOLocationID            bigint         YES
# 8         passenger_count            bigint         YES
# 9           trip_distance  double precision         YES
# 10            fare_amount  double precision         YES
# 11                  extra  double precision         YES
# 12                mta_tax  double precision         YES
# 13             tip_amount  double precision         YES
# 14           tolls_amount  double precision         YES
# 15              ehail_fee  double precision         YES
# 16  improvement_surcharge  double precision         YES
# 17           total_amount  double precision         YES
# 18           payment_type            bigint         YES
# 19              trip_type  double precision         YES
# 20   congestion_surcharge  double precision         YES
